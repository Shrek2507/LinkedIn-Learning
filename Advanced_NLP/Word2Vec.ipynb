# %% [markdown]
# ## Basics on Word2Vec

# %%
import pandas as pd
import gensim
import gensim.downloader as api

# %%
# get the embeddings from the wikipedia...
wiki_embeddings = api.load("glove-wiki-gigaword-100")

# %%
# Explore the word vector King...
wiki_embeddings['king']
# Out:
# array([-0.32307 , -0.87616 ,  0.21977 ,  0.25268 ,  0.22976 ,  0.7388  ,
#        -0.37954 , -0.35307 , -0.84369 , -1.1113  , -0.30266 ,  0.33178 ,
#        -0.25113 ,  0.30448 , -0.077491, -0.89815 ,  0.092496, -1.1407  ,
#        -0.58324 ,  0.66869 , -0.23122 , -0.95855 ,  0.28262 , -0.078848,
#         0.75315 ,  0.26584 ,  0.3422  , -0.33949 ,  0.95608 ,  0.065641,
#         0.45747 ,  0.39835 ,  0.57965 ,  0.39267 , -0.21851 ,  0.58795 ,
#        -0.55999 ,  0.63368 , -0.043983, -0.68731 , -0.37841 ,  0.38026 ,
#         0.61641 , -0.88269 , -0.12346 , -0.37928 , -0.38318 ,  0.23868 ,
#         0.6685  , -0.43321 , -0.11065 ,  0.081723,  1.1569  ,  0.78958 ,
#        -0.21223 , -2.3211  , -0.67806 ,  0.44561 ,  0.65707 ,  0.1045  ,
#         0.46217 ,  0.19912 ,  0.25802 ,  0.057194,  0.53443 , -0.43133 ,
#        -0.34311 ,  0.59789 , -0.58417 ,  0.068995,  0.23944 , -0.85181 ,
#         0.30379 , -0.34177 , -0.25746 , -0.031101, -0.16285 ,  0.45169 ,
#        -0.91627 ,  0.64521 ,  0.73281 , -0.22752 ,  0.30226 ,  0.044801,
#        -0.83741 ,  0.55006 , -0.52506 , -1.7357  ,  0.4751  , -0.70487 ,
#         0.056939, -0.7132  ,  0.089623,  0.41394 , -1.3363  , -0.61915 ,
#        -0.33089 , -0.52881 ,  0.16483 , -0.98878 ], dtype=float32)

# %%
# Find the words which are most similar to the word king based on the numeric representation
wiki_embeddings.most_similar('king')
# Out:
# [('prince', 0.7682329416275024),
#  ('queen', 0.7507690787315369),
#  ('son', 0.7020887732505798),
#  ('brother', 0.6985775232315063),
#  ('monarch', 0.6977890729904175),
#  ('throne', 0.691999077796936),
#  ('kingdom', 0.6811410188674927),
#  ('father', 0.680202841758728),
#  ('emperor', 0.6712858080863953),
#  ('ii', 0.6676074266433716)]

# %%
wiki_embeddings.most_similar('senate')
# Out:
# [('congressional', 0.8280037641525269),
#  ('republican', 0.8142463564872742),
#  ('republicans', 0.8140667676925659),
#  ('democrats', 0.8006194829940796),
#  ('senator', 0.7951719760894775),
#  ('congress', 0.7897807359695435),
#  ('gop', 0.7813129425048828),
#  ('legislature', 0.7724141478538513),
#  ('lawmakers', 0.7692404389381409),
#  ('sen.', 0.7573816180229187)]

# %% [markdown]
# ### Training On Word2Vec Model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
import re
import string
from gensim.models import Word2Vec
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score
from sklearn.metrics import precision_recall_fscore_support

# %%
# read the spam data
spamData = pd.read_csv('spam.csv', encoding='latin-1')
list_stopwords = list(stopwords.words("english"))
punctuations = string.punctuation

# %%
spamData = spamData.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], axis=1)

# %%
print("Shape Of the dataset is : ", spamData.shape)
# Out:
# Shape Of the dataset is :  (5572, 2)

# %%
spamData.head()
# Out:
#   label                                               text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
print("Columns in the dataset are : ", spamData.columns)
# Out:
# Columns in the dataset are :  Index(['label', 'text'], dtype='object')

# %%
print("Distribution of Spam and Ham in the dataset are : ")
spamData['label'].value_counts()
# Out:
# Distribution of Spam and Ham in the dataset are :
# ham     4825
# spam     747
# Name: label, dtype: int64

# %% [markdown]
# ### Cleaning Data

# %%
# function to clean the text data...
def cleanData(text):
    # Removing the punctuations from the text...
    text = "".join([word.lower() for word in text if word not in punctuations])
    
    # Splitting the text into tokens...
    tokens = re.split('\W+')
    # Removing stopwords from the tokens...
    text = [token for token in tokens if token not in list_stopwords]
    
    return text

# %%
spamData['text_clean'] = spamData['text'].apply(lambda x: gensim.utils.simple_preprocess(x))

# %%
spamData.head()
# Out:
#   label                                               text  \
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
#
#                                           text_clean
# 0  [go, until, jurong, point, crazy, available, o...
# 1                        [ok, lar, joking, wif, oni]
# 2  [free, entry, in, wkly, comp, to, win, fa, cup...
# 3     [dun, say, so, early, hor, already, then, say]
# 4  [nah, don, think, he, goes, to, usf, he, lives...

# %%
# Split the data into train and test...
X_train, X_test, y_train, y_test = train_test_split(spamData['text_clean'], spamData['label'], test_size=0.2)

# %%
# Train the Word2Vec model....
model_word2vec = Word2Vec(X_train, 
                          size=100, 
                          window=5, 
                          min_count=2)

# %%
model_word2vec.wv['king']
# Out:
# array([-3.61793488e-02, -2.82642078e-02,  3.43020819e-02, -2.67879758e-02,
#        -3.79222035e-02,  4.73653190e-02, -1.06185623e-01,  5.62766520e-03,
#         2.83254776e-02, -1.80747658e-02,  4.33870479e-02, -1.24006877e-02,
#        -2.14063842e-02, -2.35639587e-02,  6.71626031e-02, -3.23265791e-02,
#         1.46245107e-03, -4.53999266e-02, -1.84117798e-02,  4.53259610e-02,
#         4.43041772e-02, -1.16688553e-02, -5.49235847e-03, -6.08196668e-02,
#         7.40364566e-02, -4.28445455e-05,  9.80522260e-02, -4.53325175e-02,
#         6.93175290e-03, -3.95511538e-02,  7.85833821e-02,  2.89071482e-02,
#         8.20717250e-04,  6.79363012e-02, -2.20183353e-03,  1.02490976e-01,
#        -4.78897467e-02,  4.46676165e-02, -3.78106572e-02, -2.59843171e-02,
#         6.99566826e-02, -6.73679039e-02, -4.52250987e-02, -2.98104472e-02,
#         3.83341461e-02, -2.77774706e-02, -1.23660475e-01,  7.54287280e-03,
#         2.05309764e-02,  1.16777676e-03, -1.77274793e-02,  3.23546827e-02,
#         1.27530480e-02,  6.31422624e-02, -7.14484379e-02,  2.73924805e-02,
#         1.02067478e-01,  5.01750670e-02, -1.47122703e-02,  2.40593795e-02,
#         3.87442596e-02, -5.39815389e-02, -2.74483953e-03, -6.56886175e-02,
#         5.60531043e-04,  8.25338811e-03, -1.72300227e-02,  4.58004028e-02,
#         2.95264237e-02, -5.35016321e-02, -8.17973241e-02, -7.37415552e-02,
#        -2.17310973e-02,  3.20162438e-02, -4.77523766e-02,  3.71251665e-02,
#         2.36443691e-02, -3.40102948e-02, -3.43609154e-02,  4.90304269e-02,
#        -7.74063810e-04,  9.50577669e-03, -2.52292678e-02,  4.26578857e-02,
#         9.11329687e-03, -7.96006098e-02, -4.67207991e-02,  9.11347196e-02,
#         4.30362262e-02, -2.07214896e-02, -5.49799241e-02,  2.39852332e-02,
#         8.49677175e-02,  2.74247788e-02,  6.31985739e-02,  2.52381642e-03,
#        -7.84707442e-02,  1.11168891e-01,  3.17817815e-02, -8.77709873e-03],
#       dtype=float32)

# %%
# Find most similar words to king...
model_word2vec.wv.most_similar('king')
# Out:
# [('liao', 0.998287558555603),
#  ('play', 0.9982121586799622),
#  ('hello', 0.9982022643089294),
#  ('cost', 0.9981951713562012),
#  ('yeah', 0.9981865882873535),
#  ('car', 0.9981831312179565),
#  ('before', 0.998181164264679),
#  ('everything', 0.9981784820556641),
#  ('already', 0.9981728792190552),
#  ('those', 0.9981702566146851)]

# %%
# Generate the list of words the word2vec model learned word vectors for...
print(model_word2vec.wv.index2word)
# Out:
# ['you', 'to', 'the', 'and', 'in', 'is', 'me', 'my', 'it', 'for', 'your', 'of', 'that', 'call', 'have', 'on', 'are', 'now', 'so', 'can', 'but', 'not', 'do', 'get', 'or', 'be', 'at', 'we', 'with', 'if', 'ur', 'will', 'no', 'just', 'this', 'how', 'up', 'when', 'gt', 'lt', 'what', 'from', 'ok', 'free', 'all', 'out', 'll', 'know', 'go', 'good', 'day', 'like', 'am', 'then', 'its', 'there', 'was', 'got', 'only', 'come', 'he', 'text', 'time', 'love', 'want', 'send', 'txt', 'as', 'one', 'going', 'need', 'stop', 'don', 'home', 'by', 'she', 'da', 'about', 'sorry', 'see', 'lor', 'mobile', 'reply', 'today', 'still', 'back', 'tell', 'new', 'our', 'hi', 'take', 'dont', 'any', 'did', 'some', 'they', 'think', 'pls', 'her', 'week', 'here', 'dear', 'phone', 'been', 'great', 'night', 'please', 're', 'msg', 'later', 'an', 'hey', 'yes', 'oh', 'much', 'well', 'happy', 'where', 'wat', 'has', 'should', 'make', 'too', 'work', 'him', 'more', 'claim', 'ì_', 've', 'who', 'had', 'hope', 'message', 'give', 'www', 'say', 'right', 'after', 'way', 'won', 'tomorrow', 'amp', 'number', 'already', 'prize', 'doing', 'let', 'im', 'meet', 'life', 'why', 'really', 'very', 'win', 'yeah', 'ask', 'com', 'find', 'cash', 'lol', 'said', 'also', 'them', 'thanks', 'feel', 'miss', 'anything', 'last', 'would', 'uk', 'care', 'nokia', 'urgent', 'min', 'babe', 'morning', 'buy', 'were', 'first', 'cos', 'every', 'sure', 'keep', 'over', 'before', 'sent', 'money', 'even', 'pick', 'wait', 'us', 'nice', 'went', 'again', 'next', 'help', 'hello', 'contact', 'other', 'late', 'cant', 'someone', 'sms', 'which', 'many', 'his', 'sleep', 'thing', 'tone', 'something', 'could', 'chat', 'soon', 'service', 'name', 'wish', 'off', 'down', 'customer', 'ya', 'same', 'box', 'gud', 'around', 'st', 'gonna', 'special', 'always', 'friends', 'getting', 'haha', 'wan', 'done', 'place', 'lunch', 'heart', 'try', 'dun', 'things', 'god', 'tonight', 'co', 'waiting', 'per', 'leave', 'people', 'mins', 'days', 'told', 'may', 'trying', 'man', 'holiday', 'didn', 'best', 'ìï', 'guaranteed', 'use', 'cool', 'live', 'thats', 'fine', 'ppm', 'friend', 'year', 'class', 'person', 'coming', 'ready', 'th', 'draw', 'yet', 'better', 'smile', 'cs', 'stuff', 'thought', 'pm', 'talk', 'ill', 'shit', 'problem', 'end', 'house', 'never', 'yup', 'having', 'awarded', 'pobox', 'shows', 'enjoy', 'real', 'big', 'month', 'finish', 'word', 'thk', 'dat', 'being', 'hrs', 'speak', 'bit', 'receive', 'meeting', 'because', 'nothing', 'jus', 'account', 'play', 'latest', 'check', 'line', 'birthday', 'lot', 'maybe', 'chance', 'liao', 'forgot', 'into', 'few', 'yo', 'world', 'wanna', 'half', 'eat', 'car', 'job', 'landline', 'hear', 'long', 'guess', 'mind', 'plan', 'sweet', 'office', 'dunno', 'aight', 'start', 'dinner', 'than', 'another', 'guys', 'ah', 'po', 'lar', 'ringtone', 'might', 'early', 'years', 'thank', 'code', 'camera', 'offer', 'video', 'bad', 'fun', 'made', 'room', 'sir', 'probably', 'pa', 'age', 'without', 'those', 'enough', 'sat', 'watching', 'orange', 'fuck', 'princess', 'baby', 'didnt', 'remember', 'reach', 'nite', 'wk', 'quite', 'wont', 'everything', 'shall', 'ever', 'valid', 'tmr', 'tv', 'bus', 'left', 'part', 'missing', 'kiss', 'xxx', 'bed', 'minutes', 'actually', 'times', 'cost', 'shopping', 'called', 'girl', 'true', 'hour', 'working', 'nd', 'put', 'two', 'important', 'network', 'easy', 'selected', 'evening', 'town', 'entry', 'dis', 'between', 'rate', 'bt', 'look', 'abt', 'luv', 'til', 'havent', 'mob', 'dad', 'apply', 'though', 'looking', 'boy', 'alright', 'since', 'most', 'does', 'texts', 'collect', 'little', 'afternoon', 'wife', 'pain', 'must', 'weekend', 'plz', 'xx', 'guy', 'xmas', 'wot', 'collection', 'leh', 'wake', 'weekly', 'thanx', 'family', 'watch', 'show', 'gift', 'de', 'tones', 'attempt', 'while', 'able', 'away', 'brother', 'missed', 'making', 'mail', 'award', 'asked', 'came', 'leaving', 'yesterday', 'trip', 'anyway', 'nt', 'feeling', 'pay', 'friendship', 'bonus', 'colour', 'makes', 'okay', 'once', 'till', 'join', 'hair', 'den' ...

# %%
# Generate aggregated sentence vectors based on the word vectors for each word in the sentence...
w2v_vect = np.array([np.array([model_word2vec.wv[i] for i in ls if i in model_word2vec.wv.index2word])
                    for ls in X_test])

# %%
for i,v in enumerate(w2v_vect):
    print(len(X_test.iloc[i]), len(v))
# Out:
#
# 21 21
# 26 21
# 15 11
# 13 12
# 24 23
# 21 21
# 21 19
# 4 4
# 15 9
# 12 12
# 29 26
# 5 5
# 26 23
# 6 6
# 22 22
# 25 24
# 23 22
# 11 9
# 28 25
# 11 11
# 14 14
# 16 15
# 21 19
# 9 7
# 6 6
# 6 5
# 30 28
# 5 5
# 25 25
# 9 9
# 21 20
# 1 1
# 13 13
# 7 7
# 26 24
# 27 24
# 29 23
# 8 6
# 11 10
# 17 16
# 6 5
# 16 16
# 35 34
# 8 6
# 29 29
# 7 5
# 13 13
# 21 19
# 14 13
# 6 6
# 15 12
# 15 14
# 16 15
# 9 9
# 23 22
# 22 22
# 23 22
# 5 5
# 4 4
# 12 11
# 12 12
# 8 8
# 7 7
# 12 12
# 12 12
# 15 14
# 6 6
# 21 18
# 12 12
# 6 6
# 9 7
# 33 26
# 9 9
# 10 8
# 38 31
# 15 14
# 22 22
# 24 23
# 12 11
# 1 1
# 34 32
# 9 9
# 5 5
# 20 19
# 11 11
# 11 10
# 6 5
# 5 5
# 14 14
# 7 7
# 20 19
# 28 26
# 6 6
# 21 17
# 18 18
# 7 7
# 7 7
# 8 7
# 19 17
# 14 14
# 19 17
# 12 10
# 24 22
# 4 4
# 9 8
# 17 17
# 14 14
# 5 5
# 7 7
# 77 55
# 4 4
# 11 10
# 11 10
# 16 16
# 27 23
# 11 11
# 21 17

# %%
# Compute the average of the word vectors for the words contained in the sentence
w2v_vect_avg = []

for vect in w2v_vect:
    if len(vect)!=0:
        w2v_vect_avg.append(vect.mean(axis=0))
    else:
        w2v_vect_avg.append(np.zeros(100))

# %%
for i,v in enumerate(w2v_vect_avg):
    print(len(X_test.iloc[i]), len(v))
# Out:
# 16 100
# 5 100
# 8 100
# 12 100
# 14 100
# 3 100
# 26 100
# 11 100
# 9 100
# 17 100
# 20 100
# 5 100
# 27 100
# 12 100
# 24 100
# 21 100
# 5 100
# 21 100
# 25 100
# 7 100
# 6 100
# 11 100
# 10 100
# 25 100
# 7 100
# 14 100
# 25 100
# 8 100
# 23 100
# 6 100
# 30 100
# 24 100
# 30 100
# 27 100
# 18 100
# 42 100
# 12 100
# 27 100
# 3 100
# 24 100
# 6 100
# 12 100
# 10 100
# 4 100
# 35 100
# 5 100
# 24 100
# 9 100
# 10 100
# 8 100
# 21 100
# 29 100
# 6 100
# 28 100
# 26 100
# 24 100
# 21 100
# 13 100
# 17 100
# 16 100
# 26 100
# 34 100
# 11 100
# 16 100
# 4 100
# 18 100
# 20 100
# 16 100
# 3 100
# 19 100
# 4 100
# 30 100
# 12 100
# 5 100
# 4 100
# 22 100
# 1 100
# 10 100
# 3 100
# 11 100
# 29 100
# 17 100
# 7 100
# 5 100
# 11 100
# 10 100
# 23 100
# 14 100
# 28 100
# 11 100
# 17 100
# 8 100
# 18 100
# 10 100
# 25 100
# 10 100
# 20 100
# 6 100
# 17 100
# 11 100
# 16 100
# 5 100
# 4 100
# 4 100
# 5 100
# 11 100
# 14 100
# 13 100
# 10 100
# 14 100
# 6 100
# 17 100
# 5 100
# 7 100
# 17 100
# 4 100
# 28 100
# 8 100
# 6 100
# 7 100
# 10 100
# 23 100
# 11 100
# 7 100
# 7 100
# 26 100
# 22 100
# 16 100
# 21 100
# 18 100
# 4 100
# 14 100
# 23 100
# 22 100
# 6 100
# 11 100
# 11 100
# 12 100
# 20 100
# 14 100
# 28 100
# 31 100
# 9 100
# 5 100
# 1 100
# 12 100
# 5 100
# 23 100
# 10 100
# 21 100
# 9 100
# 22 100
# 7 100
# 14 100
# 33 100
# 5 100
# 24 100
# 22 100
# 21 100
# 4 100
# 4 100
# 11 100
# 5 100
# 26 100
# 8 100
# 15 100
# 4 100
# 19 100
# 3 100
# 5 100
# 4 100
# 30 100
# 9 100
# 7 100
# 8 100
# 5 100
# 23 100
# 30 100
# 9 100
# 6 100
# 22 100
# 11 100
# 6 100
# 6 100
# 21 100
# 8 100
# 30 100
# 20 100
# 13 100
# 9 100
# 21 100
# 7 100
# 14 100
# 4 100
# 25 100
# 18 100
# 9 100
# 8 100
# 22 100
# 17 100
# 8 100
# 23 100
# 4 100
# 9 100
# 6 100
# 10 100
# 6 100
# 37 100
# 32 100
# 60 100
# 11 100
# 17 100
# 11 100
# 2 100
# 19 100
# 4 100
# 26 100
# 22 100
# 4 100
# 32 100
# 27 100
# 21 100
# 30 100
# 1 100
# 5 100
# 18 100
# 18 100
# 25 100
# 25 100
# 5 100
# 4 100
# 7 100
# 12 100
# 10 100
# 9 100
# 14 100
# 29 100
# 22 100
# 21 100
# 27 100
# 3 100
# 6 100
# 11 100
# 8 100
# 5 100
# 7 100
# 2 100
# 9 100
# 8 100
# 16 100
# 5 100
# 6 100
# 15 100
# 22 100
# 25 100
# 20 100
# 60 100
# 25 100
# 6 100
# 9 100
# 4 100
# 8 100
# 25 100
# 14 100
# 24 100
# 27 100
# 20 100
# 12 100
# 11 100
# 8 100
# 9 100
# 15 100
# 15 100
# 7 100
# 8 100
# 3 100
# 10 100
# 25 100
# 6 100
# 24 100
# 23 100
# 21 100
# 28 100
# 20 100
# 8 100
# 21 100
# 8 100
# 7 100
# 27 100
# 30 100
# 23 100
# 13 100
# 5 100
# 29 100
# 8 100
# 26 100
# 5 100
# 6 100
# 7 100
# 14 100
# 9 100
# 24 100
# 6 100
# 19 100
# 12 100
# 23 100
# 16 100
# 23 100
# 11 100
# 26 100
# 4 100
# 7 100
# 26 100
# 7 100
# 22 100
# 20 100
# 6 100
# 18 100
# 7 100
# 4 100
# 11 100
# 13 100
# 19 100
# 19 100
# 11 100
# 12 100
# 5 100
# 18 100
# 17 100
# 7 100
# 4 100
# 12 100
# 5 100
# 25 100
# 6 100
# 17 100
# 10 100
# 28 100
# 7 100
# 13 100
# 15 100
# 8 100
# 5 100
# 18 100
# 9 100
# 25 100
# 6 100
# 14 100
# 30 100
# 12 100
# 4 100
# 32 100
# 4 100
# 2 100
# 25 100
# 5 100
# 4 100
# 21 100
# 8 100
# 6 100
# 6 100
# 4 100
# 6 100
# 19 100
# 6 100
# 56 100
# 17 100
# 15 100
# 4 100
# 23 100
# 25 100
# 4 100
# 3 100
# 13 100
# 30 100
# 19 100
# 15 100
# 18 100
# 25 100
# 23 100
# 17 100
# 7 100
# 4 100
# 6 100
# 23 100
# 29 100
# 14 100
# 4 100
# 7 100
# 10 100
# 25 100
# 13 100
# 14 100
# 25 100
# 6 100
# 5 100
# 4 100
# 21 100
# 19 100
# 18 100
# 12 100
# 29 100
# 50 100
# 17 100
# 7 100
# 11 100
# 17 100
# 16 100
# 4 100
# 21 100
# 5 100
# 4 100
# 152 100
# 29 100
# 7 100
# 21 100
# 4 100
# 46 100
# 17 100
# 9 100
# 27 100
# 22 100
# 6 100
# 6 100
# 21 100
# 8 100
# 33 100
# 7 100
# 20 100
# 12 100
# 4 100
# 6 100
# 6 100
# 30 100
# 12 100
# 7 100
# 4 100
# 6 100
# 8 100
# 9 100
# 9 100
# 16 100
# 13 100
# 9 100
# 13 100
# 16 100
# 4 100
# 11 100
# 6 100
# 7 100
# 11 100
# 9 100
# 2 100
# 21 100
# 6 100
# 7 100
# 22 100
# 5 100
# 10 100
# 8 100
# 41 100
# 6 100
# 8 100
# 7 100
# 14 100
# 5 100
# 14 100
# 7 100
# 12 100
# 35 100
# 12 100
# 9 100
# 3 100
# 6 100
# 21 100
# 5 100
# 24 100
# 21 100
# 7 100
# 13 100
# 4 100
# 15 100
# 7 100
# 7 100
# 6 100
# 9 100
# 28 100
# 15 100
# 9 100
# 17 100
# 17 100
# 28 100
# 27 100
# 9 100
# 17 100
# 25 100
# 6 100
# 1 100
# 6 100
# 4 100
# 13 100
# 8 100
# 27 100
# 8 100
# 4 100
# 24 100
# 13 100
# 4 100
# 17 100
# 13 100
# 5 100
# 7 100
# 18 100
# 23 100
# 16 100
# 9 100
# 26 100
# 12 100
# 29 100
# 14 100
# 24 100
# 9 100
# 11 100
# 17 100
# 8 100
# 27 100
# 10 100
# 20 100
# 14 100
# 29 100
# 8 100
# 3 100
# 17 100
# 4 100
# 22 100
# 15 100
# 2 100
# 18 100
# 11 100
# 5 100
# 8 100
# 14 100
# 5 100
# 12 100
# 4 100
# 9 100
# 26 100
# 16 100
# 24 100
# 16 100
# 5 100
# 6 100
# 4 100
# 11 100
# 9 100
# 14 100
# 13 100
# 9 100
# 12 100
# 9 100
# 26 100
# 17 100
# 13 100
# 8 100
# 10 100
# 3 100
# 1 100
# 18 100
# 6 100
# 5 100
# 3 100
# 12 100
# 6 100
# 8 100
# 18 100
# 7 100
# 7 100
# 13 100
# 22 100
# 12 100
# 4 100
# 6 100
# 15 100
# 25 100
# 11 100
# 34 100
# 9 100
# 14 100
# 22 100
# 22 100
# 13 100
# 26 100
# 5 100
# 10 100
# 30 100
# 1 100
# 3 100
# 7 100
# 27 100
# 6 100
# 21 100
# 19 100
# 23 100
# 26 100
# 21 100
# 5 100
# 20 100
# 5 100
# 7 100
# 3 100
# 7 100
# 4 100
# 15 100
# 5 100
# 30 100
# 8 100
# 6 100
# 23 100
# 8 100
# 21 100
# 8 100
# 29 100
# 29 100
# 46 100
# 15 100
# 21 100
# 9 100
# 8 100
# 14 100
# 5 100
# 77 100
# 21 100
# 12 100
# 23 100
# 7 100
# 25 100
# 13 100
# 6 100
# 20 100
# 20 100
# 25 100
# 23 100
# 23 100
# 7 100
# 19 100
# 5 100
# 4 100
# 9 100
# 10 100
# 18 100
# 9 100
# 28 100
# 6 100
# 29 100
# 16 100
# 5 100
# 7 100
# 9 100
# 12 100
# 21 100
# 22 100
# 12 100
# 20 100
# 11 100
# 13 100
# 27 100
# 11 100
# 16 100
# 8 100
# 5 100
# 13 100
# 5 100
# 13 100
# 25 100
# 4 100
# 21 100
# 6 100
# 6 100
# 17 100
# 2 100
# 14 100
# 5 100
# 30 100
# 18 100
# 15 100
# 1 100
# 5 100
# 25 100
# 17 100
# 9 100
# 6 100
# 6 100
# 9 100
# 6 100
# 6 100
# 5 100
# 16 100
# 7 100
# 8 100
# 8 100
# 10 100
# 13 100
# 7 100
# 14 100
# 19 100
# 6 100
# 10 100
# 1 100
# 7 100
# 8 100
# 4 100
# 26 100
# 19 100
# 12 100
# 14 100
# 30 100
# 24 100
# 16 100
# 22 100
# 13 100
# 9 100
# 20 100
# 28 100
# 5 100
# 6 100
# 15 100
# 5 100
# 23 100
# 25 100
# 7 100
# 8 100
# 12 100
# 14 100
# 30 100
# 14 100
# 7 100
# 26 100
# 5 100
# 2 100
# 7 100
# 15 100
# 5 100
# 15 100
# 3 100
# 17 100
# 1 100
# 8 100
# 23 100
# 18 100
# 24 100
# 31 100
# 16 100
# 26 100
# 24 100
# 7 100
# 8 100
# 6 100
# 21 100
# 10 100
# 20 100
# 12 100
# 3 100
# 16 100
# 12 100
# 4 100
# 18 100
# 16 100
# 26 100
# 9 100
# 7 100
# 8 100
# 15 100
# 12 100
# 16 100
# 3 100
# 6 100
# 12 100
# 39 100
# 22 100
# 12 100
# 25 100
# 9 100
# 35 100
# 13 100
# 12 100
# 4 100
# 6 100
# 10 100
# 13 100
# 6 100
# 10 100
# 17 100
# 10 100
# 7 100
# 13 100
# 19 100
# 5 100
# 18 100
# 6 100
# 25 100
# 2 100
# 5 100
# 6 100
# 23 100
# 9 100
# 7 100
# 10 100
# 16 100
# 26 100
# 5 100
# 3 100
# 8 100
# 1 100
# 16 100
# 8 100
# 9 100
# 23 100
# 22 100
# 8 100
# 6 100
# 20 100
# 5 100
# 21 100
# 7 100
# 6 100
# 28 100
# 11 100
# 7 100
# 9 100
# 4 100
# 6 100
# 6 100
# 5 100
# 30 100
# 4 100
# 21 100
# 27 100
# 25 100
# 19 100
# 7 100
# 8 100
# 24 100
# 24 100
# 7 100
# 30 100
# 5 100
# 12 100
# 13 100
# 33 100
# 19 100
# 5 100
# 20 100
# 24 100
# 10 100
# 22 100
# 7 100
# 34 100
# 7 100
# 7 100
# 22 100
# 5 100
# 7 100
# 17 100
# 31 100
# 14 100
# 9 100
# 58 100
# 28 100
# 22 100
# 4 100
# 4 100
# 7 100
# 13 100
# 4 100
# 3 100
# 21 100
# 5 100
# 8 100
# 5 100
# 23 100
# 6 100
# 14 100
# 16 100
# 5 100
# 9 100
# 7 100
# 55 100
# 7 100
# 16 100
# 6 100
# 12 100
# 5 100
# 8 100
# 14 100
# 8 100
# 8 100
# 6 100
# 49 100
# 6 100
# 21 100
# 16 100
# 30 100
# 10 100
# 25 100
# 7 100
# 4 100
# 23 100
# 8 100
# 25 100
# 4 100
# 110 100
# 8 100
# 14 100
# 24 100
# 18 100
# 12 100
# 18 100
# 16 100
# 5 100
# 36 100
# 4 100
# 14 100
# 27 100
# 5 100
# 8 100
# 4 100
# 16 100
# 9 100
# 5 100
# 6 100
# 7 100
# 8 100
# 7 100
# 22 100
# 5 100
# 13 100
# 10 100
# 11 100
# 11 100
# 6 100
# 7 100
# 5 100
# 8 100
# 5 100
# 4 100
# 13 100
# 5 100
# 5 100
# 10 100
# 20 100
# 26 100
# 25 100
# 8 100
# 11 100
# 26 100
# 5 100
# 15 100
# 8 100
# 5 100
# 29 100
# 10 100
# 15 100
# 28 100
# 11 100
# 6 100
# 10 100
# 18 100
# 5 100
# 11 100
# 19 100
# 26 100
# 18 100
# 9 100
# 23 100
# 6 100
# 7 100
# 20 100
# 12 100
# 6 100
# 5 100
# 15 100
# 6 100
# 29 100
# 12 100
# 14 100
# 5 100
# 34 100
# 4 100
# 6 100
# 6 100
# 11 100
# 29 100
# 5 100
# 4 100
# 22 100
# 9 100
# 24 100
# 26 100
# 21 100
# 26 100
# 15 100
# 13 100
# 24 100
# 21 100
# 21 100
# 4 100
# 15 100
# 12 100
# 29 100
# 5 100
# 26 100
# 6 100
# 22 100
# 25 100
# 23 100
# 11 100
# 28 100
# 11 100
# 14 100
# 16 100
# 21 100
# 9 100
# 6 100
# 6 100
# 30 100
# 5 100
# 25 100
# 9 100
# 21 100
# 1 100
# 13 100
# 7 100
# 26 100
# 27 100
# 29 100
# 8 100
# 11 100
# 17 100
# 6 100
# 16 100
# 35 100
# 8 100
# 29 100
# 7 100
# 13 100
# 21 100
# 14 100
# 6 100
# 15 100
# 15 100
# 16 100
# 9 100
# 23 100
# 22 100
# 23 100
# 5 100
# 4 100
# 12 100
# 12 100
# 8 100
# 7 100
# 12 100
# 12 100
# 15 100
# 6 100
# 21 100
# 12 100
# 6 100
# 9 100
# 33 100
# 9 100
# 10 100
# 38 100
# 15 100
# 22 100
# 24 100
# 12 100
# 1 100
# 34 100
# 9 100
# 5 100
# 20 100
# 11 100
# 11 100
# 6 100
# 5 100
# 14 100
# 7 100
# 20 100
# 28 100
# 6 100
# 21 100
# 18 100
# 7 100
# 7 100
# 8 100
# 19 100
# 14 100
# 19 100
# 12 100
# 24 100
# 4 100
# 9 100
# 17 100
# 14 100
# 5 100
# 7 100
# 77 100
# 4 100
# 11 100
# 11 100
# 16 100
# 27 100
# 11 100
# 21 100
